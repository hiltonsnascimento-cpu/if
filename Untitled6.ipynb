# %% [markdown]
# <a href="https://colab.research.google.com/github/hiltonsnascimento-cpu/if/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
idade = int(input("Digite sua idade: "))
if idade >= 18:
  print("Apto para voto")
else:
  print("Não Apto")
# Out:
# Digite sua idade: 25
# Apto para voto

# %% [markdown]
# Criar um sistema de senha, a senha tem que ser senai2026, se for essa senha aparece:"Liberado", senão acesso bloqueado.

# %%
senha = input("Digite sua senha: ")
if senha == "Drop Where":
  print("Liberado")
else:
  print("Acesso bloqueado")
# Out:
# Digite sua senha: senai2026
# Acesso bloqueado
